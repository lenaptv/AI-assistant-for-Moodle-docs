# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Parsing

# %%
import os
import aiohttp
import asyncio
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Настройки
BASE_URL = "https://docs.moodle.org/500/en/Main_page"
DOMAIN_PREFIX = "https://docs.moodle.org"
OUTPUT_DIR = "/content/drive/MyDrive/moodle_docs9"
CONCURRENCY = 10
MAX_PAGES = 20000

# Создаём директории, если не существуют
os.makedirs(OUTPUT_DIR, exist_ok=True)

visited_urls = set()
semaphore = asyncio.Semaphore(CONCURRENCY)

# Фразы для фильтрации нежелательных страниц
irrelevant_phrases = [
     "Talk:",
    "Category:",
    "Special:",
    "Template:",

]

def is_valid_link(href):
    # Фильтруем по ссылкам, исключаем медиафайлы и неинформативные ссылки
    excluded_exts = [".png", ".jpg", ".jpeg", ".gif", ".svg", ".ico", ".css", ".js"]
    if any(href.lower().endswith(ext) for ext in excluded_exts):
        return False
    if not href.startswith("/500/en/"):
        return False
    if any(x in href for x in ["Special:", "Category:", "Talk:", "Template:", "action=edit", "oldid=", "index.php?"]):
        return False
    return True

async def fetch(session, url):
    try:
        async with session.get(url) as resp:
            if resp.status == 200:
                return await resp.text()
            print(f"⚠️ HTTP {resp.status} для {url}")
            return None
    except Exception as e:
        print(f"❌ Ошибка запроса {url}: {e}")
        return None

async def fetch_and_parse(session, url, to_visit):
    async with semaphore:
        if url in visited_urls or len(visited_urls) >= MAX_PAGES:
            return
        visited_urls.add(url)

        html = await fetch(session, url)
        if not html:
            return

        soup = BeautifulSoup(html, "html.parser")

        title = soup.find("h1")
        title_text = title.get_text(strip=True) if title else "Untitled"
        filename = url.split("/")[-1] or "index"
        filename = filename.replace("?", "_") + ".md"

        content_div = soup.find("div", {"id": "content"})
        if content_div:
            text = content_div.get_text(separator="\n", strip=True)

            # Фильтрация только для НЕ главной страницы
            if url != BASE_URL:
                matched_phrase = None
                for phrase in irrelevant_phrases:
                    if phrase in text:
                        matched_phrase = phrase
                        break

                if matched_phrase is not None:
                    print(f"⛔ Пропущено из-за '{matched_phrase}': {url}")
                    return

                if len(text) < 300:
                    print(f"⛔ Пропущено из-за короткого текста (<300 символов): {url}")
                    return

            filepath = os.path.join(OUTPUT_DIR, filename)
            with open(filepath, "w", encoding="utf-8") as f:
                f.write(f"# {title_text}\n\n{text}")
            print(f"✅ Сохранено: {filename}")

        # Собираем новые ссылки для обхода
        for a in soup.select("a[href]"):
            href = a['href']
            if is_valid_link(href):
                full_url = urljoin(DOMAIN_PREFIX, href)
                if full_url not in visited_urls:
                    to_visit.add(full_url)

async def crawl_all():
    async with aiohttp.ClientSession() as session:
        to_visit = {BASE_URL}
        while to_visit and len(visited_urls) < MAX_PAGES:
            current_batch = list(to_visit)
            to_visit.clear()
            tasks = [fetch_and_parse(session, url, to_visit) for url in current_batch]
            await asyncio.gather(*tasks)

# Для запуска в Jupyter / Colab (если нужно)
import nest_asyncio
nest_asyncio.apply()

# Запуск основного процесса
await crawl_all()
# Out:
# ✅ Сохранено: Main_page.md
# ✅ Сохранено: Activities.md
# ✅ Сохранено: Add_students.md
# ✅ Сохранено: Admin_quick_guide.md
# ✅ Сохранено: Managing_a_Moodle_course.md
# ✅ Сохранено: Add_users.md
# ✅ Сохранено: Moodle_app_notifications.md
# ✅ Сохранено: MoodleDocs:About.md
# ✅ Сохранено: New_for_mobile.md
# ✅ Сохранено: Course_homepage.md
# ✅ Сохранено: New_for_students.md
# ✅ Сохранено: Moodle_app_features.md
# ✅ Сохранено: Quiz_activity.md
# ✅ Сохранено: Installing_plugins.md
# ✅ Сохранено: Teacher_quick_guide.md
# ✅ Сохранено: Adding_a_new_course.md
# ✅ Сохранено: Table_of_Contents.md
# ✅ Сохранено: Tracking_progress.md
# ✅ Сохранено: Assignment_activity.md
# ✅ Сохранено: Site_appearance.md
# ✅ Сохранено: Moodle_app_additional_features.md
# ✅ Сохранено: Forum_activity.md
# ✅ Сохранено: Workshop_activity.md
# ✅ Сохранено: New_for_teachers.md
# ✅ Сохранено: Moodle_app.md
# ✅ Сохранено: Creating_Moodle-app-friendly_courses.md
# ✅ Сохранено: MoodleDocs:General_disclaimer.md
# ✅ Сохранено: Managing_a_Moodle_site.md
# ✅ Сохранено: Working_with_files.md
# ✅ Сохранено: New_features.md
# ✅ Сохранено: MoodleDocs:Privacy.md
# ✅ Сохранено: Installation_quick_guide.md
# ✅ Сохранено: Features.md
# ✅ Сохранено: New_for_administrators.md
# ✅ Сохранено: Database_settings.md
# ✅ Сохранено: Installing_Moodle_from_Git_repository#Installing_a_contributed_extension_from_its_Git_repository.md
# ✅ Сохранено: Developer_tools.md
# ✅ Сохранено: AI_usage_report.md
# ✅ Сохранено: Using_Glossary.md
# ✅ Сохранено: Navigation_block.md
# ✅ Сохранено: Activity_completion_FAQ.md
# ✅ Сохранено: Course_restore.md
# ✅ Сохранено: Configuring_the_Router.md
# ✅ Сохранено: Guide_for_new_administrators.md
# ✅ Сохранено: Forum_settings.md
# ✅ Сохранено: MySQL.md
# ✅ Сохранено: Page.md
# ✅ Сохранено: language_packs.md
# ✅ Сохранено: Youtube_videos_repository.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Juan_Leyva
# ✅ Сохранено: Standards.md
# ✅ Сохранено: Privacy_in_the_Moodle_app.md
# ✅ Сохранено: Accessibility.md
# ✅ Сохранено: Advanced_grading_methods.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Environment
# ✅ Сохранено: SSL_certificate_for_moodle.org.md
# ✅ Сохранено: URL_resource_settings.md
# ✅ Сохранено: No_authentication.md
# ✅ Сохранено: Feedback_FAQ.md
# ✅ Сохранено: Upgrading_FAQ.md
# ✅ Сохранено: Add_a_new_user.md
# ✅ Сохранено: Enrolment_FAQ.md
# ✅ Сохранено: Moodle_site_-_basic_structure.md
# ✅ Сохранено: Search_and_replace_tool.md
# ✅ Сохранено: Participation_report.md
# ✅ Сохранено: course:sectionvisibility.md
# ✅ Сохранено: File_system_repository.md
# ✅ Сохранено: Authentication_FAQ.md
# ✅ Сохранено: Calendar_import.md
# ✅ Сохранено: Email_protection_filter.md
# ✅ Сохранено: File_resource_FAQ.md
# ✅ Сохранено: User_menu.md
# ✅ Сохранено: Choice_settings.md
# ✅ Сохранено: Additional_name_fields.md
# ✅ Сохранено: Feedback.md
# ✅ Сохранено: Filters.md
# ✅ Сохранено: course:movesections.md
# ✅ Сохранено: Calendar_FAQ.md
# ✅ Сохранено: Web_services.md
# ✅ Сохранено: Competencies.md
# ✅ Сохранено: Managing_roles.md
# ✅ Сохранено: Course_overview_report.md
# ✅ Сохранено: site:approvecourse.md
# ✅ Сохранено: Enrolments.md
# ✅ Сохранено: User_profile_fields.md
# ✅ Сохранено: Quiz_FAQ.md
# ✅ Сохранено: Restoring_file_aliases.md
# ✅ Сохранено: Activity_completion_settings.md
# ✅ Сохранено: Cohorts.md
# ✅ Сохранено: Video.md
# ✅ Сохранено: Performance_overview.md
# ✅ Сохранено: Pedagogy.md
# ✅ Сохранено: More_features.md
# ✅ Сохранено: Server_files_repository.md
# ✅ Сохранено: Activity_backup.md
# ✅ Сохранено: Lesson_FAQ.md
# ✅ Сохранено: Guest_role.md
# ✅ Сохранено: My_latest_badges_block.md
# ✅ Сохранено: Grouping_users.md
# ✅ Сохранено: WebDAV_repository.md
# ✅ Сохранено: SCORM_module.md
# ✅ Сохранено: Accounts_FAQ.md
# ✅ Сохранено: Outcomes.md
# ✅ Сохранено: Assignment_settings.md
# ✅ Сохранено: Guest_access.md
# ✅ Сохранено: Quiz_settings.md
# ✅ Сохранено: Statistics.md
# ✅ Сохранено: Server_settings.md
# ✅ Сохранено: Data_formats.md
# ✅ Сохранено: Notes_FAQ.md
# ✅ Сохранено: Filter_settings.md
# ✅ Сохранено: Resources.md
# ✅ Сохранено: Logged_in_user_block.md
# ✅ Сохранено: Text_editor_FAQ.md
# ✅ Сохранено: Filters_FAQ.md
# ✅ Сохранено: Workshop.md
# ✅ Сохранено: Installation.md
# ✅ Сохранено: Question_behaviours.md
# ✅ Сохранено: Course_list.md
# ✅ Сохранено: Activities_block.md
# ✅ Сохранено: Activity_restore.md
# ✅ Сохранено: Database_transfer.md
# ✅ Сохранено: Manual_accounts.md
# ✅ Сохранено: portfolios.md
# ✅ Сохранено: Performance_settings.md
# ✅ Сохранено: Simple_calculated_question_type.md
# ✅ Сохранено: Performance_FAQ.md
# ✅ Сохранено: Language_settings.md
# ✅ Сохранено: Administration_via_command_line.md
# ✅ Сохранено: Using_Quiz.md
# ✅ Сохранено: Installing_a_new_theme.md
# ✅ Сохранено: Security_FAQ.md
# ✅ Сохранено: Database_templates.md
# ✅ Сохранено: LDAP_enrolment.md
# ✅ Сохранено: Using_badges.md
# ✅ Сохранено: Login_block.md
# ✅ Сохранено: Book_module.md
# ✅ Сохранено: Wiki_activity.md
# ✅ Сохранено: Using_Forum.md
# ✅ Сохранено: Logging.md
# ✅ Сохранено: Boost_theme.md
# ✅ Сохранено: Import_groups.md
# ✅ Сохранено: Upload_users.md
# ✅ Сохранено: Using_Feedback.md
# ✅ Сохранено: Course_overview_block.md
# ✅ Сохранено: Theme_settings.md
# ✅ Сохранено: Year-end_procedures.md
# ✅ Сохранено: Wiki.md
# ✅ Сохранено: Automatic_updates_deployment.md
# ✅ Сохранено: Moodle_App_Block_support.md
# ✅ Сохранено: Course_FAQ.md
# ✅ Сохранено: Installing_Moodle.md
# ✅ Сохранено: Reducing_spam_in_Moodle.md
# ✅ Сохранено: Download_course_content.md
# ✅ Сохранено: Question_categories.md
# ✅ Сохранено: Data_privacy.md
# ✅ Сохранено: Working_with_media.md
# ✅ Сохранено: Bulk_enrolments.md
# ✅ Сохранено: Creating_mobile-friendly_courses.md
# ✅ Сохранено: Social_activities.md
# ✅ Сохранено: Competency_breakdown_report.md
# ✅ Сохранено: cron.md
# ✅ Сохранено: Recent_activity_block.md
# ✅ Сохранено: Maintenance_mode.md
# ✅ Сохранено: Glossary.md
# ✅ Сохранено: Courses.md
# ✅ Сохранено: Audio.md
# ✅ Сохранено: URL_resource_FAQ.md
# ✅ Сохранено: Password_salting.md
# ✅ Сохранено: Workshop_settings.md
# ✅ Сохранено: Book_settings.md
# ✅ Сохранено: Database.md
# ✅ Сохранено: Database_auto-linking_filter.md
# ✅ Сохранено: Enrolment_methods.md
# ✅ Сохранено: Publish_as_LTI_tool.md
# ✅ Сохранено: IMS_content_package_settings.md
# ✅ Сохранено: Lesson_activity.md
# ✅ Сохранено: Blogs.md
# ✅ Сохранено: Front_page_settings.md
# ✅ Сохранено: Managing_repositories.md
# ✅ Сохранено: Tag_settings.md
# ✅ Сохранено: Choice_activity.md
# ✅ Сохранено: Book.md
# ✅ Сохранено: Google_Drive_converter.md
# ✅ Сохранено: Book_FAQ.md
# ✅ Сохранено: Using_Lesson.md
# ✅ Сохранено: Search_forums_block.md
# ✅ Сохранено: Managing_grades.md
# ✅ Сохранено: Display_H5P_filter.md
# ✅ Сохранено: Calendar_block.md
# ✅ Сохранено: Database_activity.md
# ✅ Сохранено: Caching.md
# ✅ Сохранено: Assignments.md
# ✅ Сохранено: Flat_file.md
# ✅ Сохранено: Managing_blocks.md
# ✅ Сохранено: Forum.md
# ✅ Сохранено: Document_converters.md
# ✅ Сохранено: Using_tags.md
# ✅ Сохранено: Upload_a_file_repository.md
# ✅ Сохранено: Workshop_FAQ.md
# ✅ Сохранено: Moodle_migration.md
# ✅ Сохранено: Plagiarism_prevention.md
# ✅ Сохранено: Building_Database.md
# ✅ Сохранено: Conditional_activities.md
# ✅ Сохранено: User_policies.md
# ✅ Сохранено: Moodle_Mobile_features.md
# ✅ Сохранено: Moodle_Mobile_quiz_offline_attempts.md
# ✅ Сохранено: Managing_content.md
# ✅ Сохранено: Redis_cache_store.md
# ✅ Сохранено: Grades_FAQ.md
# ✅ Сохранено: Administration_block.md
# ✅ Сохранено: Plugins_FAQ.md
# ✅ Сохранено: MathJax_filter.md
# ✅ Сохранено: File_resource.md
# ✅ Сохранено: Media_FAQ.md
# ✅ Сохранено: Front_page_FAQ.md
# ✅ Сохранено: Comments_FAQ.md
# ✅ Сохранено: Language_customisation#Database_error.md
# ✅ Сохранено: Custom_reports.md
# ✅ Сохранено: Category_enrolments.md
# ✅ Сохранено: Front_page.md
# ✅ Сохранено: Flickr.md
# ✅ Сохранено: Questions_FAQ.md
# ✅ Сохранено: Global_search.md
# ✅ Сохранено: Security.md
# ✅ Сохранено: Recent_files_repository.md
# ✅ Сохранено: Using_Database.md
# ✅ Сохранено: Bulk_course_upload.md
# ✅ Сохранено: Wikimedia_repository.md
# ✅ Сохранено: Notifications.md
# ✅ Сохранено: RSS_feeds_FAQ.md
# ✅ Сохранено: Course_completion_settings.md
# ✅ Сохранено: Choice_FAQ.md
# ✅ Сохранено: Portfolios_FAQ.md
# ✅ Сохранено: Experimental_settings.md
# ✅ Сохранено: Mobile_web_services.md
# ✅ Сохранено: Matching_question_type.md
# ✅ Сохранено: Page_resource.md
# ✅ Сохранено: Using_RSS_feeds.md
# ✅ Сохранено: Plugin_Review_Criteria.md
# ✅ Сохранено: Main_menu_block.md
# ✅ Сохранено: Label_FAQ.md
# ✅ Сохранено: File:Moodle_features_students.pdf.md
# ✅ Сохранено: Activity_completion_report.md
# ✅ Сохранено: H5P_activity.md
# ✅ Сохранено: Recycle_bin.md
# ✅ Сохранено: Block.md
# ✅ Сохранено: Self_completion_block.md
# ✅ Сохранено: MoodleNet.md
# ✅ Сохранено: Licenses.md
# ✅ Сохранено: Moodle_Mobile_availability_plugin.md
# ✅ Сохранено: Comments.md
# ✅ Сохранено: Self_enrolment.md
# ✅ Сохранено: Philosophy.md
# ✅ Сохранено: Using_Course_completion.md
# ✅ Сохранено: RSS_feeds.md
# ✅ Сохранено: Web_services_FAQ.md
# ✅ Сохранено: Calendar_settings.md
# ✅ Сохранено: Browse_list_of_users.md
# ✅ Сохранено: HTTP.md
# ✅ Сохранено: Notes.md
# ✅ Сохранено: language.md
# ✅ Сохранено: Flickr_block.md
# ✅ Сохранено: Feedback_settings.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/Using_Workshop
# ✅ Сохранено: Student_role.md
# ✅ Сохранено: Grade_import.md
# ✅ Сохранено: Unenrolment.md
# ✅ Сохранено: Cohort_sync.md
# ✅ Сохранено: Site_registration.md
# ✅ Сохранено: Course_backup.md
# ✅ Сохранено: Editing_text.md
# ✅ Сохранено: Logs.md
# ✅ Сохранено: Tags_FAQ.md
# ✅ Сохранено: Reports_FAQ.md
# ✅ Сохранено: Using_Calendar.md
# ✅ Сохранено: Language_packs.md
# ✅ Сохранено: Enrolment_plugins.md
# ✅ Сохранено: Essay_question_type.md
# ✅ Сохранено: AI_providers.md
# ✅ Сохранено: Glossary_auto-linking_filter.md
# ✅ Сохранено: IMS_content_package.md
# ✅ Сохранено: URL_downloader_repository.md
# ✅ Сохранено: Enrolment_key.md
# ✅ Сохранено: Using_Book.md
# ✅ Сохранено: Course_settings.md
# ✅ Сохранено: User_pictures.md
# ✅ Сохранено: SCORM_FAQ.md
# ✅ Сохранено: Cleanup.md
# ✅ Сохранено: Skydrive_repository.md
# ✅ Сохранено: Images.md
# ✅ Сохранено: Security_recommendations.md
# ✅ Сохранено: Communication.md
# ✅ Сохранено: Moodle_version.md
# ✅ Сохранено: Header_and_footer.md
# ✅ Сохранено: HTML_block.md
# ✅ Сохранено: LTI_External_tool_activity.md
# ✅ Сохранено: Quiz_results_block.md
# ✅ Сохранено: Grader_report.md
# ✅ Сохранено: Grading_quick_guide.md
# ✅ Сохранено: Competencies_FAQ.md
# ✅ Сохранено: Question_instances_report.md
# ✅ Сохранено: Course_index.md
# ✅ Сохранено: Payment_gateways.md
# ✅ Сохранено: Cron.md
# ✅ Сохранено: Mobile_app.md
# ✅ Сохранено: Language_customisation.md
# ✅ Сохранено: Performance.md
# ✅ Сохранено: User_quick_guide.md
# ✅ Сохранено: Youtube_block.md
# ✅ Сохранено: Search_and_replace.md
# ✅ Сохранено: Merlot.org_repository.md
# ✅ Сохранено: Moodle_Mobile_SCORM_player.md
# ✅ Сохранено: File.md
# ✅ Сохранено: RSS_feeds_block.md
# ✅ Сохранено: Moodle_app_H5P_support#Working_offline.md
# ✅ Сохранено: Description_question_type.md
# ✅ Сохранено: Wiki_FAQ.md
# ✅ Сохранено: Moodle_Mobile.md
# ✅ Сохранено: Dropbox_repository.md
# ✅ Сохранено: Blog_menu_block.md
# ✅ Сохранено: Portfolios.md
# ✅ Сохранено: Latest_news_block.md
# ✅ Сохранено: Language_FAQ.md
# ✅ Сохранено: IMS_Enterprise.md
# ✅ Сохранено: Groups.md
# ✅ Сохранено: Gradebook.md
# ✅ Сохранено: Block_settings.md
# ✅ Сохранено: Blogs_FAQ.md
# ✅ Сохранено: Site_policies.md
# ✅ Сохранено: Course_creator_role.md
# ✅ Сохранено: Grades.md
# ✅ Сохранено: Word_censorship_filter.md
# ✅ Сохранено: Import_questions.md
# ✅ Сохранено: Using_Assignment.md
# ✅ Сохранено: Internet_Information_Services.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/Workshop_grading_strategies
# ✅ Сохранено: Glossary_settings.md
# ✅ Сохранено: Display_emoticons_as_images_filter.md
# ✅ Сохранено: SCORM_settings.md
# ✅ Сохранено: Competency_frameworks.md
# ✅ Сохранено: Using_Blogs.md
# ✅ Сохранено: File_resource_settings.md
# ✅ Сохранено: Event_monitoring.md
# ✅ Сохранено: Using_SCORM.md
# ✅ Сохранено: Enrolment.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/Guidelines_for_Contributors
# ✅ Сохранено: Mobile_app_notifications.md
# ✅ Сохранено: Restrict_access.md
# ✅ Сохранено: Manual_enrolment.md
# ✅ Сохранено: Upcoming_events_block.md
# ✅ Сохранено: Questions.md
# ✅ Сохранено: Automated_course_backup.md
# ✅ Сохранено: Learning_plans.md
# ✅ Сохранено: SMS_gateways.md
# ✅ Сохранено: Using_web_services.md
# ✅ Сохранено: Flickr_public_repository.md
# ✅ Сохранено: Upgrade_overview.md
# ✅ Сохранено: Upgrading.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Themes_FAQ
# ✅ Сохранено: Courses_block.md
# ✅ Сохранено: Moodle_app_guide_for_admins.md
# ✅ Сохранено: Messaging_settings.md
# ✅ Сохранено: Moodle_app_offline_features.md
# ✅ Сохранено: Site-wide_reports.md
# ✅ Сохранено: Assignment_FAQ.md
# ✅ Сохранено: Feedback_activity.md
# ✅ Сохранено: TinyMCE_editor.md
# ✅ Сохранено: User_tours.md
# ✅ Сохранено: BigBlueButton.md
# ✅ Сохранено: course:setcurrentsection.md
# ✅ Сохранено: Email-based_self-registration.md
# ✅ Сохранено: Recent_blog_entries_block.md
# ✅ Сохранено: Quiz.md
# ✅ Сохранено: LDAP_authentication.md
# ✅ Сохранено: External_tool_FAQ.md
# ✅ Сохранено: Participants.md
# ✅ Сохранено: Backup.md
# ✅ Сохранено: Assignment_module.md
# ✅ Сохранено: Authenticated_user_role.md
# ✅ Сохранено: Wiki_settings.md
# ✅ Сохранено: course:delete.md
# ✅ Сохранено: Administrator.md
# ✅ Сохранено: AI_policy_acceptance_report.md
# ✅ Сохранено: Course_creator.md
# ✅ Сохранено: Comments_block.md
# ✅ Сохранено: SCORM_activity.md
# ✅ Сохранено: Assign_roles.md
# ✅ Сохранено: Tags_block.md
# ✅ Сохранено: Random_glossary_entry_block.md
# ✅ Сохранено: Export_questions.md
# ✅ Сохранено: Using_Wiki.md
# ✅ Сохранено: course_settings.md
# ✅ Сохранено: Activity_completion.md
# ✅ Сохранено: Permissions.md
# ✅ Сохранено: External_tool.md
# ✅ Сохранено: Moodle_key_terms.md
# ✅ Сохранено: Git_for_Administrators.md
# ✅ Сохранено: Blocks_FAQ.md
# ✅ Сохранено: Forum_FAQ.md
# ✅ Сохранено: Calendar.md
# ✅ Сохранено: Mail_configuration.md
# ✅ Сохранено: Standard_roles.md
# ✅ Сохранено: Mentees_block.md
# ✅ Сохранено: Manager_role.md
# ✅ Сохранено: Creating_Moodle_Mobile_friendly_sites.md
# ✅ Сохранено: Calculated_multichoice_question_type.md
# ✅ Сохранено: Roles_FAQ.md
# ✅ Сохранено: Teacher_role.md
# ✅ Сохранено: Debugging.md
# ✅ Сохранено: Creating_custom_roles.md
# ✅ Сохранено: Override_permissions.md
# ✅ Сохранено: Blocks.md
# ✅ Сохранено: Groupings.md
# ✅ Сохранено: Numerical_question_type.md
# ✅ Сохранено: Glossary_activity.md
# ✅ Сохранено: Flickr_repository.md
# ✅ Сохранено: Moodle_Mobile_guide_for_admins.md
# ✅ Сохранено: History.md
# ✅ Сохранено: No_login.md
# ✅ Сохранено: Activity_names_auto-linking_filter.md
# ✅ Сохранено: Text_editor.md
# ✅ Сохранено: Custom_link.md
# ✅ Сохранено: Scheduled_tasks.md
# ✅ Сохранено: Licences.md
# ✅ Сохранено: Lesson.md
# ✅ Сохранено: Convert_URLs_into_links_filter.md
# ✅ Сохранено: Building_Lesson.md
# ✅ Сохранено: Course_requester_role.md
# ✅ Сохранено: My_private_files_block.md
# ✅ Сохранено: Location.md
# ✅ Сохранено: Section_links_block.md
# ✅ Сохранено: PostgreSQL.md
# ✅ Сохранено: Grade_penalties.md
# ✅ Сохранено: Database_FAQ.md
# ✅ Сохранено: Multi-language_content_filter.md
# ✅ Сохранено: site_summary_block.md
# ✅ Сохранено: Config_changes_report.md
# ✅ Сохранено: Installation_FAQ.md
# ✅ Сохранено: Policies.md
# ✅ Сохранено: Repositories_FAQ.md
# ✅ Сохранено: Activities_overview.md
# ✅ Сохранено: Using_Label.md
# ✅ Сохранено: Managing_portfolios.md
# ✅ Сохранено: Performance_recommendations.md
# ✅ Сохранено: Course_completion_FAQ.md
# ✅ Сохранено: Ollama_API_provider.md
# ✅ Сохранено: Grade_export.md
# ✅ Сохранено: Google_Drive_repository.md
# ✅ Сохранено: blogs.md
# ✅ Сохранено: Using_restrict_access.md
# ✅ Сохранено: EQUELLA_repository.md
# ✅ Сохранено: Bulk_user_actions.md
# ✅ Сохранено: Course_categories.md
# ✅ Сохранено: LTI_External_tools.md
# ✅ Сохранено: File_download.md
# ✅ Сохранено: Events_list_report.md
# ✅ Сохранено: Question_banks.md
# ✅ Сохранено: Moodle_app_SCORM_player.md
# ✅ Сохранено: Badges_FAQ.md
# ✅ Сохранено: IMS_Common_Cartridge_import_and_export.md
# ✅ Сохранено: upload_courses.md
# ✅ Сохранено: Backup_and_restore_FAQ.md
# ✅ Сохранено: Messaging_FAQ.md
# ✅ Сохранено: MUC_FAQ.md
# ✅ Сохранено: Messaging.md
# ✅ Сохранено: Google_Docs_portfolio.md
# ✅ Сохранено: Privacy_officer_role.md
# ✅ Сохранено: Box.net_repository.md
# ✅ Сохранено: GDPR.md
# ✅ Сохранено: Amazon_S3_repository.md
# ✅ Сохранено: Plagiarism_prevention_FAQ.md
# ✅ Сохранено: Language.md
# ✅ Сохранено: Choice.md
# ✅ Сохранено: Badges_settings.md
# ✅ Сохранено: Themes.md
# ✅ Сохранено: Tags.md
# ✅ Сохранено: User_profiles.md
# ✅ Сохранено: Question_bank.md
# ✅ Сохранено: Keyholder.md
# ✅ Сохранено: Managing_activities.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/Embedded_Answers_(Cloze)_question_type
# ✅ Сохранено: Moodle_app_security.md
# ✅ Сохранено: Picasa.md
# ✅ Сохранено: Lesson_settings.md
# ✅ Сохранено: My_courses.md
# ✅ Сохранено: External_database_enrolment.md
# ✅ Сохранено: Upload_courses.md
# ✅ Сохранено: Calculated_question_type.md
# ✅ Сохранено: File_picker.md
# ✅ Сохранено: Using_Page.md
# ✅ Сохранено: Matrix.md
# ✅ Сохранено: Private_files.md
# ✅ Сохранено: Documentation_philosophy.md
# ✅ Сохранено: Shibboleth.md
# ✅ Сохранено: subsection:addinstance.md
# ✅ Сохранено: Analytics.md
# ✅ Сохранено: working_with_files.md
# ✅ Сохранено: Page_resource_settings.md
# ✅ Сохранено: Moodle_app_H5P_support.md
# ✅ Сохранено: Moodle_Mobile_FAQ.md
# ✅ Сохранено: Moodle_app_FAQ.md
# ✅ Сохранено: Managing_authentication.md
# ✅ Сохранено: Reusing_activities.md
# ✅ Сохранено: Using_External_tool.md
# ✅ Сохранено: Building_Quiz.md
# ✅ Сохранено: External_database_authentication.md
# ✅ Сохранено: System_paths.md
# ✅ Сохранено: Blog_settings.md
# ✅ Сохранено: SCORM.md
# ✅ Сохранено: Usage.md
# ✅ Сохранено: Course_relative_dates.md
# ✅ Сохранено: Course_formats.md
# ✅ Сохранено: About_Moodle.md
# ✅ Сохранено: Blog_tags_block.md
# ✅ Сохранено: Moodle_Mobile_Quiz_module.md
# ✅ Сохранено: Folder_module_settings.md
# ✅ Сохранено: URL_resource.md
# ✅ Сохранено: Online_users_block.md
# ✅ Сохранено: Label.md
# ✅ Сохранено: Site_security_settings.md
# ✅ Сохранено: IMS_content_package_FAQ.md
# ✅ Сохранено: Course_completion_status_block.md
# ✅ Сохранено: Security_checks.md
# ✅ Сохранено: Multiple_Choice_question_type.md
# ✅ Сохранено: MariaDB.md
# ✅ Сохранено: Using_Activity_completion.md
# ✅ Сохранено: Glossary_FAQ.md
# ✅ Сохранено: Administration_FAQ.md
# ✅ Сохранено: Restrict_access_FAQ.md
# ✅ Сохранено: Site_administrators.md
# ✅ Сохранено: badges.md
# ✅ Сохранено: Moodle_app_plans.md
# ✅ Сохранено: Other_users.md
# ✅ Сохранено: Site_backup.md
# ✅ Сохранено: Import_course_data.md
# ✅ Сохранено: Restrict_access_settings.md
# ✅ Сохранено: Text_and_media_area.md
# ✅ Сохранено: Badges.md
# ✅ Сохранено: Folder_resource.md
# ✅ Сохранено: H5P.md
# ✅ Сохранено: Navigation.md
# ✅ Сохранено: Classic_theme.md
# ✅ Сохранено: Managing_tags.md
# ✅ Сохранено: Activity_chooser.md
# ✅ Сохранено: Managing_plagiarism_prevention.md
# ✅ Сохранено: Assignment.md
# ✅ Сохранено: Course_meta_link.md
# ✅ Сохранено: Installation_Quickstart.md
# ✅ Сохранено: Grade_settings.md
# ✅ Сохранено: Multimedia_plugins_filter.md
# ✅ Сохранено: Managing_filters.md
# ✅ Сохранено: Folder.md
# ✅ Сохранено: Roles_and_permissions.md
# ✅ Сохранено: Course_reports.md
# ✅ Сохранено: Question_types.md
# ✅ Сохранено: Quiz_reports.md
# ✅ Сохранено: Non-editing_teacher_role.md
# ✅ Сохранено: Privacy.md
# ✅ Сохранено: Enrolment_on_payment.md
# ✅ Сохранено: Authentication.md
# ✅ Сохранено: Messages_block.md
# ✅ Сохранено: Scales.md
# ✅ Сохранено: Session_handling.md
# ✅ Сохранено: Content_bank.md
# ✅ Сохранено: Box.net_portfolio.md
# ✅ Сохранено: Standard_themes.md
# ✅ Сохранено: Course_enrolment.md
# ✅ Сохранено: File_picker_FAQ.md
# ✅ Сохранено: Apache.md
# ✅ Сохранено: Groups_FAQ.md
# ✅ Сохранено: Using_Choice.md
# ✅ Сохранено: Page_FAQ.md
# ✅ Сохранено: Reset_course.md
# ✅ Сохранено: Admin_tools.md
# ✅ Сохранено: External_tool_settings.md
# ✅ Сохранено: Stealth_activities.md
# ✅ Сохранено: False_question_type.md
# ✅ Сохранено: Repositories.md
# ✅ Сохранено: Short-Answer_question_type.md
# ✅ Сохранено: Managing_questions.md
# ✅ Сохранено: Managing_accounts.md
# ✅ Сохранено: Mahara.md
# ✅ Сохранено: Using_roles.md
# ✅ Сохранено: Media_embedding.md
# ✅ Сохранено: recycle_bin.md
# ✅ Сохранено: Managing_badges.md
# ✅ Сохранено: RSS_feeds_settings.md
# ✅ Сохранено: Activity_report.md
# ✅ Сохранено: TeX_notation_filter.md
# ✅ Сохранено: Formatting_text.md
# ✅ Сохранено: Dashboard.md
# ✅ Сохранено: About_Moodle_FAQ.md
# ✅ Сохранено: Universal_Office_Converter_(unoconv).md
# ✅ Сохранено: Algebra_filter.md
# ✅ Сохранено: Label_module_settings.md
# ✅ Сохранено: Paypal_enrolment.md
# ✅ Сохранено: Folder_FAQ.md
# ✅ Сохранено: Course_completion.md
# ✅ Сохранено: Admin_bookmarks_block.md
# ✅ Сохранено: Picasa_web_album_repository.md
# ✅ Сохранено: Groupings_FAQ.md
# ✅ Сохранено: PHP.md
# ✅ Сохранено: Manager.md
# ✅ Сохранено: Nginx.md
# ✅ Сохранено: Multiple_Choice_question_type#Penalty_factor.md
# ✅ Сохранено: Database_fields.md
# ✅ Сохранено: label.md
# ✅ Сохранено: recordrtc:recordscreen.md
# ✅ Сохранено: amf:use.md
# ✅ Сохранено: premium:useautocorrect.md
# ✅ Сохранено: course:overridecompletion.md
# ✅ Сохранено: systemd.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20241009071814%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Сохранено: comment:delete.md
# ✅ Сохранено: h5p:upload.md
# ✅ Сохранено: Allow_role_overrides.md
# ✅ Сохранено: Reverse_proxy_frontend.md
# ✅ Сохранено: Quiz_quick_guide.md
# ✅ Сохранено: site:sendmessage.md
# ✅ Сохранено: upload:view.md
# ✅ Сохранено: txt:publish.md
# ✅ Сохранено: grade:edit.md
# ✅ Сохранено: user:manageblocks.md
# ✅ Сохранено: backup:downloadfile.md
# ✅ Сохранено: Analytics_FAQ.md
# ✅ Сохранено: comments:addinstance.md
# ✅ Сохранено: Learning_analytics_indicators.md
# ✅ Сохранено: Tools_for_backing_up_server_files.md
# ✅ Сохранено: MoodleBox.md
# ✅ Сохранено: Development:Grades#API_for_communication_with_modules.2Fblocks.md
# ✅ Сохранено: Hacked_site_recovery.md
# ✅ Сохранено: wiki:editcomment.md
# ✅ Сохранено: Portfolio_Plugin_for_Evernote.md
# ✅ Сохранено: Roles_and_capabilities.md
# ✅ Сохранено: bigbluebuttonbn:viewallrecordingformats.md
# ✅ Сохранено: myoverview:myaddinstance.md
# ✅ Сохранено: grader_report.md
# ✅ Сохранено: course:configurecoursecommunication.md
# ✅ Сохранено: grade:lock.md
# ✅ Сохранено: Decision_FAQ.md
# ✅ Сохранено: Quiz_settings#Review_options.md
# ✅ Сохранено: Calculated_question_type#Correct_answer_formula_syntax.md
# ✅ Сохранено: Filters_used_on_the_Moodle.org_forums.md
# ✅ Сохранено: badges:manageownbadges.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/User:James_Neill
# ✅ Сохранено: forum:splitdiscussions.md
# ✅ Сохранено: course:reset.md
# ✅ Сохранено: Server_cluster.md
# ✅ Сохранено: ad-hoc_contributed_reports#List_of_users_with_language.md
# ✅ Сохранено: General_grade_settings#Graded_Roles.md
# ✅ Сохранено: Report_builder.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20230611090918%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Сохранено: Performance_recommendations#Performance_of_different_Moodle_modules.md
# ✅ Сохранено: Course_formats#Contributed_Course_Formats.md
# ✅ Сохранено: HTTPS.md
# ✅ Сохранено: Using_TeX_Notation.md
# ✅ Сохранено: imscp:addinstance.md
# ✅ Сохранено: Database_presets.md
# ✅ Сохранено: premium:usetinymcespellchecker.md
# ✅ Сохранено: Forum_poster_role.md
# ✅ Сохранено: online_users:viewlist.md
# ✅ Сохранено: Google_OAuth_2.0_setup.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20220111123247%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xbf in position 10: invalid start byte
# ✅ Сохранено: Competency_reviewer.md
# ✅ Сохранено: Advanced_features.md
# ✅ Сохранено: Background.md
# ✅ Сохранено: Lesson_FAQ#Can_I_change_the_End_of_Lesson_page_display.md
# ✅ Сохранено: Differentiator_local_plugin.md
# ✅ Сохранено: Lesson_questions.md
# ✅ Сохранено: comment:view.md
# ✅ Сохранено: Filter.md
# ✅ Сохранено: report_security_check_google.md
# ✅ Сохранено: LTI_External_tool_FAQ.md
# ✅ Сохранено: grade_export.md
# ✅ Сохранено: Administration_via_command_line#Scheduled_tasks.md
# ✅ Сохранено: zip.md
# ✅ Сохранено: H5P#Manage_H5P_content_types.md
# ✅ Сохранено: page:addinstance.md
# ✅ Сохранено: badges:configuremessages.md
# ✅ Сохранено: direct:view.md
# ✅ Сохранено: policy:viewacceptances.md
# ✅ Сохранено: Guest.md
# ✅ Сохранено: File_FAQ.md
# ✅ Сохранено: Drag_and_drop_into_text_question_type.md
# ✅ Сохранено: All_factor_report.md
# ✅ Сохранено: Calculated_question_type#Penalty_factor.md
# ✅ Сохранено: Unix_or_Linux_Installation.md
# ✅ Сохранено: Risks.md
# ✅ Сохранено: outline:view.md
# ✅ Сохранено: Windows_installation_using_Git.md
# ✅ Сохранено: Using_Conditional_activities.md
# ✅ Сохранено: Compiling_PHP_from_source.md
# ✅ Сохранено: grade:manageletters.md
# ✅ Сохранено: Youtube_videos.md
# ✅ Сохранено: dataprivacy:managedataregistry.md
# ✅ Сохранено: my:manageblocks.md
# ✅ Сохранено: Lesson_question_types.md
# ✅ Сохранено: Context.md
# ✅ Сохранено: Preg_question_type.md
# ✅ Сохранено: Matching_question_type#See_also.md
# ✅ Сохранено: category:synchronised.md
# ✅ Сохранено: Glossaries.md
# ✅ Сохранено: premium:useformatpainter.md
# ✅ Сохранено: matrix:moderator.md
# ✅ Сохранено: Course_formats#Weekly_sections.md
# ✅ Сохранено: Moodle_development_environment_with_Git_submodules.md
# ✅ Сохранено: Mail_configuration#Outgoing_mail_configuration.md
# ✅ Сохранено: h5pactivity:view.md
# ✅ Сохранено: Blogger_role.md
# ✅ Сохранено: restore:restorecourse.md
# ✅ Сохранено: user:editmessageprofile.md
# ✅ Сохранено: forum:addquestion.md
# ✅ Сохранено: course:changesummary.md
# ✅ Сохранено: Grade_locking#In_grade_categories.md
# ✅ Сохранено: Offline_quiz_activity.md
# ✅ Сохранено: Clusters.md
# ✅ Сохранено: forum:postprivatereply.md
# ✅ Сохранено: dataprivacy:managedatarequests.md
# ✅ Сохранено: choice:addinstance.md
# ✅ Сохранено: courses.md
# ✅ Сохранено: Grade_editing#Overridden.md
# ✅ Сохранено: lti:requesttooladd.md
# ✅ Сохранено: Administration_via_command_line#Reset_user_password.md
# ✅ Сохранено: site:configview.md
# ✅ Сохранено: site:viewfullnames.md
# ✅ Сохранено: Drag_and_drop_markers_question_type.md
# ✅ Сохранено: xml:view.md
# ✅ Сохранено: ad-hoc_contributed_reports.md
# ✅ Сохранено: Database_activity_settings.md
# ✅ Сохранено: Site_Backup_for_Low-tech_Users.md
# ✅ Сохранено: Database_activity_module.md
# ✅ Сохранено: Quiz_responses_report.md
# ✅ Сохранено: report_security_check_noauth.md
# ✅ Сохранено: filter_multiembed.md
# ✅ Сохранено: Grade_viewer.md
# ✅ Сохранено: Managing_authentication#Allow_accounts_with_same_email.md
# ✅ Сохранено: Advanced_theme_settings.md
# ✅ Сохранено: webservice:createtoken.md
# ✅ Сохранено: feedback:mapcourse.md
# ✅ Сохранено: E-Mail_flag_for_users.md
# ✅ Сохранено: File_module_settings.md
# ✅ Сохранено: Unexpected_installation_halts.md
# ✅ Сохранено: Upload_cohorts.md
# ✅ Сохранено: Quiz_settings#How_to_allow_only_some_students_(not_all)_to_review_the_quiz_correct_answers_how_to_do_this.md
# ✅ Сохранено: Completion_tracking.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Help:Editing
# ✅ Сохранено: report_security_check_preventexecpath.md
# ✅ Сохранено: dataprivacy:makedatadeletionrequestsforchildren.md
# ✅ Сохранено: Level_up!_quick_guide.md
# ✅ Сохранено: Comments#Enabling_comments.md
# ✅ Сохранено: Metacourse_examples_of_use.md
# ✅ Сохранено: Language_packs#Parent_language_packs_and_child_language_packs.md
# ✅ Сохранено: CLI.md
# ✅ Сохранено: How_can_we_show_our_students_only_the_wrong_answers.md
# ✅ Сохранено: Installation_FAQ#How_to_enable_and_check_PHP_error_logs.md
# ✅ Сохранено: forum:viewhiddentimedposts.md
# ✅ Сохранено: Installing_Moodle#Recheck_PHP_settings.md
# ✅ Сохранено: Web_services_authentication.md
# ✅ Сохранено: course:managescales.md
# ✅ Сохранено: paypal:config.md
# ✅ Сохранено: assign:receivegradernotifications.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Translation_FAQ
# ✅ Сохранено: folder:addinstance.md
# ✅ Сохранено: Using_Assignment#Annotating_PDF_files.md
# ✅ Сохранено: rest:use.md
# ✅ Сохранено: user:viewdetails.md
# ✅ Сохранено: book:viewhiddenchapters.md
# ✅ Сохранено: restore:uploadfile.md
# ✅ Сохранено: Grade_hiding.md
# ✅ Сохранено: URL.md
# ✅ Сохранено: user:viewhiddendetails.md
# ✅ Сохранено: Bloom%27s_taxonomy.md
# ✅ Сохранено: competency:userevidencemanageown.md
# ✅ Сохранено: role:switchroles.md
# ✅ Сохранено: forum.md
# ✅ Сохранено: grade:unlock.md
# ✅ Сохранено: competency:competencymanage.md
# ✅ Сохранено: edit.md
# ✅ Сохранено: course:enrolreview.md
# ✅ Сохранено: contentbank:accesscoursecontent.md
# ✅ Сохранено: Grade_history.md
# ✅ Сохранено: Recent_files.md
# ✅ Сохранено: blog:search.md
# ✅ Сохранено: Course.md
# ✅ Сохранено: H5P_essay.md
# ✅ Сохранено: File_download_portfolio.md
# ✅ Сохранено: index#Cleaning_up_spam.md
# ✅ Сохранено: Adaptable_theme.md
# ✅ Сохранено: bigbluebuttonbn:seepresentation.md
# ✅ Сохранено: backup:configure.md
# ✅ Сохранено: Roles_settings.md
# ✅ Сохранено: Social_activities_block.md
# ✅ Сохранено: text_editor.md
# ✅ Сохранено: HTML_table_format.md
# ✅ Сохранено: Quiz_statistics_report.md
# ✅ Сохранено: Azure_AI_API_provider.md
# ✅ Сохранено: xls:publish.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Import_and_export_FAQ
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Tertiary_education
# ✅ Сохранено: Jumps.md
# ✅ Сохранено: Performance_recommendations#PHP_performance.md
# ✅ Сохранено: course:create.md
# ✅ Сохранено: Activity_report#Individual_Activity_Report.md
# ✅ Сохранено: Email_setup_gmail.md
# ✅ Сохранено: User_default_preferences.md
# ✅ Сохранено: Effective_quiz_practices.md
# ✅ Сохранено: restore:viewautomatedfilearea.md
# ✅ Сохранено: Third-party_question_types.md
# ✅ Сохранено: Building_Quiz#Adding_questions.md
# ✅ Сохранено: HTML_in_Moodle.md
# ✅ Сохранено: Learning_plans_block.md
# ✅ Сохранено: user:manageownblocks.md
# ✅ Сохранено: H5P_FAQ.md
# ✅ Сохранено: onedrive:view.md
# ✅ Сохранено: Available_update_notifications.md
# ✅ Сохранено: Upload_user_pictures.md
# ✅ Сохранено: feedback:edititems.md
# ✅ Сохранено: role:manage.md
# ✅ Сохранено: fee:manage.md
# ✅ Сохранено: OneDrive_repository.md
# ✅ Сохранено: assign:submit.md
# ✅ Сохранено: premium:usechecklist.md
# ✅ Сохранено: contentbank:view.md
# ✅ Сохранено: self:manage.md
# ✅ Сохранено: coursefiles:view.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Pierre_Pichet
# ✅ Сохранено: Front_Page_settings.md
# ✅ Сохранено: assignment.md
# ✅ Сохранено: user:manageownfiles.md
# ✅ Сохранено: course:viewscales.md
# ✅ Сохранено: Installing_contributed_modules_or_plugins.md
# ✅ Сохранено: imscp:view.md
# ✅ Сохранено: JMeter_test_plan_generator.md
# ✅ Сохранено: Code_syntax_highlighting.md
# ✅ Сохранено: ai:viewaiusagereport.md
# ✅ Сохранено: page:view.md
# ✅ Сохранено: course:tag.md
# ✅ Сохранено: Upgrade.md
# ✅ Сохранено: Portfolio_module.md
# ✅ Сохранено: backup:backupsection.md
# ✅ Сохранено: Blog.md
# ✅ Сохранено: No_Email.md
# ✅ Сохранено: contentbank:accessgeneralcontent.md
# ✅ Сохранено: Ordering_question_type.md
# ✅ Сохранено: phpinfo.md
# ✅ Сохранено: user:managesyspages.md
# ✅ Сохранено: Multimedia_plugins.md
# ✅ Сохранено: Google_Drive_portfolio.md
# ✅ Сохранено: Global_search_block.md
# ✅ Сохранено: user:update.md
# ✅ Сохранено: Timeline_block.md
# ✅ Сохранено: dataprivacy:downloadownrequest.md
# ✅ Сохранено: Latest_badges_block.md
# ✅ Сохранено: OpenLiteSpeed.md
# ✅ Сохранено: report_security_check_guestrole.md
# ✅ Сохранено: YouTube_videos_repository.md
# ✅ Сохранено: Learning_Analytics_Enriched_Rubric.md
# ✅ Сохранено: assign:view.md
# ✅ Сохранено: question:tagall.md
# ✅ Сохранено: merlot:view.md
# ✅ Сохранено: backup:anonymise.md
# ✅ Сохранено: SCORM_FAQ#Moodle_changes_cmi.core.lesson_status_from_.22completed.22_or_.22passed.22_to_.22failed.22.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/MoodleDocs:Templates
# ✅ Сохранено: Cron_with_Unix_or_Linux#High_performance_cron_tasks.md
# ✅ Сохранено: block:edit.md
# ✅ Сохранено: Hot_Potatoes.md
# ✅ Сохранено: Word_table_format.md
# ✅ Сохранено: Groups#No_groups.md
# ✅ Сохранено: forum:canoverridediscussionlock.md
# ✅ Сохранено: report_security_check_displayerrors.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/CSS
# ✅ Сохранено: Using_certainty-based_marking.md
# ✅ Сохранено: file_picker.md
# ✅ Сохранено: site_backup.md
# ✅ Сохранено: h5p:use.md
# ✅ Сохранено: File_system_repository_FAQ.md
# ✅ Сохранено: Support_contact.md
# ✅ Сохранено: Settings_block.md
# ✅ Сохранено: Administration_FAQ#How_do_the_limits_on_uploaded_files_work.3F.md
# ✅ Сохранено: performance_recommendations.md
# ✅ Сохранено: Emoticon_images.md
# ✅ Сохранено: Database_activity_FAQ.md
# ✅ Сохранено: Building_Feedback.md
# ✅ Сохранено: Dropbox.md
# ✅ Сохранено: Installing_Moodle_on_SmarterASP.NET.md
# ✅ Сохранено: Advanced_Maths_Tools.md
# ✅ Сохранено: Teacher_role#Bulk_assigning_the_Teacher_role_in_a_category.md
# ✅ Сохранено: online_users:myaddinstance.md
# ✅ Сохранено: Sharing_question_banks.md
# ✅ Сохранено: Policies_plugin.md
# ✅ Сохранено: h5p:updatelibraries.md
# ✅ Сохранено: course:reviewotherusers.md
# ✅ Сохранено: lti:addpreconfiguredinstance.md
# ✅ Сохранено: Sessions_FAQ.md
# ✅ Сохранено: upstart.md
# ✅ Сохранено: user_bulk.md
# ✅ Сохранено: Scales#Creating_a_new_scale.md
# ✅ Сохранено: site:doclinks.md
# ✅ Сохранено: Glossary_module.md
# ✅ Сохранено: site:viewuseridentity.md
# ✅ Сохранено: Web_services_test_client.md
# ✅ Сохранено: book:addinstance.md
# ✅ Сохранено: Contributing_a_translation.md
# ✅ Сохранено: Main_Page.md
# ✅ Сохранено: Word_censorship.md
# ✅ Сохранено: Repository.md
# ✅ Сохранено: Dashboard#Blocks_not_available_on_the_Dashboard.md
# ✅ Сохранено: xml:publish.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Mathematics
# ✅ Сохранено: restore:restoresection.md
# ✅ Сохранено: Redis_cache_store#Installing_Redis_server.md
# ✅ Сохранено: Moodle_Mobile_quiz.md
# ✅ Сохранено: book:read.md
# ✅ Сохранено: Help:Login.md
# ✅ Сохранено: restore:userinfo.md
# ✅ Сохранено: Redis_cache_store#Installing_Redis_php_driver.md
# ✅ Сохранено: competency:planmanageowndraft.md
# ✅ Сохранено: online_users:addinstance.md
# ✅ Сохранено: Assignment_settings#Use_marking_.28grading.29_workflow.md
# ✅ Сохранено: How_to_get_a_security_key.md
# ✅ Сохранено: Gift_with_medias_format.md
# ✅ Сохранено: MySQL#Configure_full_UTF-8_support.md
# ✅ Сохранено: Performance_recommendations#Obtain_a_baseline_benchmark.md
# ✅ Сохранено: Text_editor#Displaying_the_HTML_code.md
# ✅ Сохранено: comments:myaddinstance.md
# ✅ Сохранено: Building_Lesson#Add_a_content_page.md
# ✅ Сохранено: Buttons_course_format.md
# ✅ Сохранено: Course_overview.md
# ✅ Сохранено: exportimscp:export.md
# ✅ Сохранено: grade:managegradingforms.md
# ✅ Сохранено: Calculated_question_type#Wildcards_and_datasets.md
# ✅ Сохранено: badges:myaddinstance.md
# ✅ Сохранено: Course_copy.md
# ✅ Сохранено: Numerical_question_type#Penalty_factor.md
# ✅ Сохранено: Multi_language_content.md
# ✅ Сохранено: Grade_calculations.md
# ✅ Сохранено: Learning_plan_viewer.md
# ✅ Сохранено: Postgres.md
# ✅ Сохранено: Mirroring_Moodle.md
# ✅ Сохранено: Windows_installation.md
# ✅ Сохранено: policy:acceptbehalf.md
# ✅ Сохранено: Observer_role.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Sharing_Cart
# ✅ Сохранено: Calculated_question_type#Correct_answer_formula.md
# ✅ Сохранено: Installing_AMP.md
# ✅ Сохранено: PayPal_enrolment.md
# ✅ Сохранено: Common_module_settings.md
# ✅ Сохранено: Repurpose_resources_content_type_plugin.md
# ✅ Сохранено: Installing_unoconv#Run_a_unoconv_listener.md
# ✅ Сохранено: lti:manage.md
# ✅ Сохранено: lti:admin.md
# ✅ Сохранено: Using_Assignment#Granting_extensions.md
# ✅ Сохранено: Adding_a_question_page.md
# ✅ Сохранено: Game_module.md
# ✅ Сохранено: Step-by-step_Installation_Guide_for_Ubuntu.md
# ✅ Сохранено: lighttpd.md
# ✅ Сохранено: Quizzes.md
# ✅ Сохранено: Site_restore.md
# ✅ Сохранено: Health_center.md
# ✅ Сохранено: Text_block.md
# ✅ Сохранено: duedate:manage.md
# ✅ Сохранено: resource:addinstance.md
# ✅ Сохранено: feedback:viewreports.md
# ✅ Сохранено: competency_breakdown_report.md
# ✅ Сохранено: forum:movediscussions.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20210118192409%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xbf in position 10: invalid start byte
# ✅ Сохранено: Moodle_Mobile_guide_for_admins#Custom_language_strings.md
# ✅ Сохранено: accessibilitychecker:use.md
# ✅ Сохранено: Cron_with_MAC_OS_X.md
# ✅ Сохранено: Moodle_app_guide_for_admins#Custom_language_strings.md
# ✅ Сохранено: Using_Forum#Moving_a_discussion.md
# ✅ Сохранено: folder:view.md
# ✅ Сохранено: Messages.md
# ✅ Сохранено: Activity_results_block.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/install_on_OS_X
# ✅ Сохранено: Browser_sessions.md
# ✅ Сохранено: user:view.md
# ✅ Сохранено: Front_Page.md
# ✅ Сохранено: enrolment_key.md
# ✅ Сохранено: premium:usecasechange.md
# ✅ Сохранено: csv:view.md
# ✅ Сохранено: Add_from_MoodleNet.md
# ✅ Сохранено: h5p:useeditor.md
# ✅ Сохранено: Manager_role#Assigning_the_role_of_Manager_at_the_Category_level.md
# ✅ Сохранено: fee:unenrolself.md
# ✅ Сохранено: h5pactivity:addinstance.md
# ✅ Сохранено: contentbank:useeditor.md
# ✅ Сохранено: lti:addinstance.md
# ✅ Сохранено: DragMath_equation_editor.md
# ✅ Сохранено: Folder_resource_settings.md
# ✅ Сохранено: index#Live_logs_from_the_past_hour.md
# ✅ Сохранено: file.md
# ✅ Сохранено: competency:planmanagedraft.md
# ✅ Сохранено: contentbank:upload.md
# ✅ Сохранено: link:use.md
# ✅ Сохранено: tag:editblocks.md
# ✅ Сохранено: Test_course_generator.md
# ✅ Сохранено: OAuth_2_services.md
# ✅ Сохранено: Navigation_bar.md
# ✅ Сохранено: page_resource.md
# ✅ Сохранено: Feedback_template_creator.md
# ✅ Сохранено: uploadcourse:use.md
# ✅ Сохранено: paypal:unenrolself.md
# ✅ Сохранено: Starred_courses_block.md
# ✅ Сохранено: self:unenrol.md
# ✅ Сохранено: forum:replypost.md
# ✅ Сохранено: h5pactivity:reviewattempts.md
# ✅ Сохранено: index#Comments_report.md
# ✅ Сохранено: course:creategroupconversations.md
# ✅ Сохранено: xls:view.md
# ✅ Сохранено: General_grade_settings.md
# ✅ Сохранено: s3:view.md
# ✅ Сохранено: grade:view.md
# ✅ Сохранено: Profile.md
# ✅ Сохранено: IIS.md
# ✅ Сохранено: areafiles:view.md
# ✅ Сохранено: Quiz_submission_email_notification.md
# ✅ Сохранено: Email-based_self_registration.md
# ✅ Сохранено: Preferences.md
# ✅ Сохранено: Site_notifications.md
# ✅ Сохранено: Speech_tools.md
# ✅ Сохранено: feedback:view.md
# ✅ Сохранено: Accessibility_review_block.md
# ✅ Сохранено: AI_placements.md
# ✅ Сохранено: badges:configurecriteria.md
# ✅ Сохранено: TeX_notation.md
# ✅ Сохранено: Database_module.md
# ✅ Сохранено: wikimedia:view.md
# ✅ Сохранено: grade:hide.md
# ✅ Сохранено: course:viewhiddenactivities.md
# ✅ Сохранено: How_to_check_your_database_for_corruption.md
# ✅ Сохранено: Moodle_Production_Server_with_GIT.md
# ✅ Сохранено: badges:awardbadge.md
# ✅ Сохранено: Site_home_FAQ.md
# ✅ Сохранено: Security_keys.md
# ✅ Сохранено: Backpacks.md
# ✅ Сохранено: paypal:manage.md
# ✅ Сохранено: PhET_simulations.md
# ✅ Сохранено: Multianswer_question_type.md
# ✅ Сохранено: blog:viewdrafts.md
# ✅ Сохранено: APC_user_cache_(APCu).md
# ✅ Сохранено: skydrive:view.md
# ✅ Сохранено: Grade_items.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20230713085836%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Сохранено: Automated_backup_setup.md
# ✅ Сохранено: Quiz_manual_grading_report.md
# ✅ Сохранено: site:manageblocks.md
# ✅ Сохранено: question:tagmine.md
# ✅ Сохранено: dropbox:view.md
# ✅ Сохранено: premium:useexport.md
# ✅ Сохранено: Lesson_module#Multiple_choice.md
# ✅ Сохранено: calendar:manageownentries.md
# ✅ Сохранено: grade:export.md
# ✅ Сохранено: index#Backups_report.md
# ✅ Сохранено: h5pactivity:submit.md
# ✅ Сохранено: Mobile_app_notifications#Troubleshooting.md
# ✅ Сохранено: choice:deleteresponses.md
# ✅ Сохранено: Cohorts#Creating_a_cohort.md
# ✅ Сохранено: quiz.md
# ✅ Сохранено: Box_repository.md
# ✅ Сохранено: Import_glossary_entries.md
# ✅ Сохранено: recent_activity:viewaddupdatemodule.md
# ✅ Сохранено: role:review.md
# ✅ Сохранено: loglive:view.md
# ✅ Сохранено: Moodle_Mobile_app.md
# ✅ Сохранено: premium:usetypography.md
# ✅ Сохранено: local:view.md
# ✅ Сохранено: notes:view.md
# ✅ Сохранено: Forum_settings#Common_module_settings.md
# ✅ Сохранено: manual:config.md
# ✅ Сохранено: Masquerading.md
# ✅ Сохранено: Security_overview_report.md
# ✅ Сохранено: folder.md
# ✅ Сохранено: Plagiarism_Prevention_Ouriginal.md
# ✅ Сохранено: user:editownmessageprofile.md
# ✅ Сохранено: Site_home.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20221229110756%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Сохранено: Creating_custom_roles#Example_custom_roles.md
# ✅ Сохранено: data:writeentry.md
# ✅ Сохранено: outcomes:view.md
# ✅ Сохранено: Email-based_self-registration#Enable_reCAPTCHA_element.md
# ✅ Сохранено: Manage_authentication.md
# ✅ Сохранено: h5p:addembed.md
# ✅ Сохранено: premium:use.md
# ✅ Сохранено: restore:configure.md
# ✅ Сохранено: Lesson_module.md
# ✅ Сохранено: assign:viewblinddetails.md
# ✅ Сохранено: Roles_FAQ#How_can_I_prevent_a_user_from_changing_their_own_password_.md
# ✅ Сохранено: Cohorts_FAQ.md
# ✅ Сохранено: How_to_fix_just_one_bug_without_upgrading.md
# ✅ Сохранено: ods:publish.md
# ✅ Сохранено: LDAP_authentication#Table_of_Contents.md
# ✅ Сохранено: Latest_announcements_block.md
# ✅ Сохранено: premium:uselinkchecker.md
# ✅ Сохранено: Moodle.md
# ✅ Сохранено: OAuth_2_Microsoft_service.md
# ✅ Сохранено: maintenance_mode.md
# ✅ Сохранено: policy:managedocs.md
# ✅ Сохранено: premium:useeditimage.md
# ✅ Сохранено: Groups#Separate_groups.md
# ✅ Сохранено: launchd.md
# ✅ Сохранено: Privacy_Officer_role.md
# ✅ Сохранено: question:flag.md
# ✅ Сохранено: backup:backuptargetimport.md
# ✅ Сохранено: MySQL_full_unicode_support.md
# ✅ Сохранено: glossary:exportownentry.md
# ✅ Сохранено: filesystem:view.md
# ✅ Сохранено: paypal:unenrol.md
# ✅ Сохранено: grade:sharegradingforms.md
# ✅ Сохранено: forum:rate.md
# ✅ Сохранено: Flickr.com_portfolio.md
# ✅ Сохранено: Using_analytics.md
# ✅ Сохранено: dataprivacy:requestdeleteforotheruser.md
# ✅ Сохранено: ai:viewaipolicyacceptancereport.md
# ✅ Сохранено: groupings.md
# ✅ Сохранено: Site_home_settings.md
# ✅ Сохранено: Roles.md
# ✅ Сохранено: report_security_check_mediafilterswf.md
# ✅ Сохранено: course:viewhiddencourses.md
# ✅ Сохранено: blog:create.md
# ✅ Сохранено: lti:addcoursetool.md
# ✅ Сохранено: lesson.md
# ✅ Сохранено: report_security_check_emailchangeconfirmation.md
# ✅ Сохранено: iAssign.md
# ✅ Сохранено: Installing_plugins#Plugins_overview.md
# ✅ Сохранено: my:configsyspages.md
# ✅ Сохранено: report_security_check_cookiesecure.md
# ✅ Сохранено: notes:manage.md
# ✅ Сохранено: resources.md
# ✅ Сохранено: Multi-factor_authentication.md
# ✅ Сохранено: Forum_permissions.md
# ✅ Сохранено: IPA_filter.md
# ✅ Сохранено: glossary.md
# ✅ Сохранено: restore:createuser.md
# ✅ Сохранено: Moodle_app_guide_for_admins#Custom_menu_items.md
# ✅ Сохранено: txt:view.md
# ✅ Сохранено: question:config.md
# ✅ Сохранено: Cron_on_1and1_shared_servers.md
# ✅ Сохранено: Upload_users#Fields_that_can_be_included.md
# ✅ Сохранено: Complete_Install_Packages_for_Mac_OS_X.md
# ✅ Сохранено: RecordRTC.md
# ✅ Сохранено: choice:readresponses.md
# ✅ Сохранено: Session_handling#Redis_session_driver.md
# ✅ Сохранено: Creating_SCORM_Content.md
# ✅ Сохранено: OAuth_2_authentication.md
# ✅ Сохранено: How_to_create_and_enable_a_web_service.md
# ✅ Сохранено: autosave:use.md
# ✅ Сохранено: Amazon_EC2_Cloud_Services_Installation.md
# ✅ Сохранено: TeX_filter.md
# ✅ Сохранено: user:loginas.md
# ✅ Сохранено: Analytics_settings.md
# ✅ Сохранено: Announcements.md
# ✅ Сохранено: Grade_letters.md
# ✅ Сохранено: Share_to_MoodleNet.md
# ✅ Сохранено: upload_users.md
# ✅ Сохранено: html:use.md
# ⛔ Пропущено из-за 'Template:': https://docs.moodle.org/500/en/MoodleDocs:Guidelines_for_contributors
# ✅ Сохранено: course:viewhiddenuserfields.md
# ✅ Сохранено: GIFT_format.md
# ✅ Сохранено: Authenticated_user.md
# ✅ Сохранено: course:changefullname.md
# ✅ Сохранено: dataprivacy:downloadallrequests.md
# ✅ Сохранено: Manage_roles.md
# ✅ Сохранено: restore:restoreactivity.md
# ✅ Сохранено: mariadb_(10.4.28-MariaDB).md
# ✅ Сохранено: Translation.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Reports
# ✅ Сохранено: report_security_check_defaultuserrole.md
# ✅ Сохранено: initd.md
# ✅ Сохранено: restore:restoretargetimport.md
# ✅ Сохранено: site:readallmessages.md
# ✅ Сохранено: folder:managefiles.md
# ✅ Сохранено: Keyholder_role.md
# ✅ Сохранено: qbehaviour_interactiveexplain.md
# ✅ Сохранено: data:exportownentry.md
# ✅ Сохранено: Text_and_media_area_settings.md
# ✅ Сохранено: feedback:receivemail.md
# ✅ Сохранено: Installing_MSSQL_for_PHP.md
# ✅ Сохранено: role:override.md
# ✅ Сохранено: report_security_check_unsecuredataroot.md
# ✅ Сохранено: assign:editothersubmission.md
# ✅ Сохранено: Quiz_module.md
# ✅ Сохранено: Vendor_directory_security_check.md
# ✅ Сохранено: glossary:comment.md
# ✅ Сохранено: premium:usefootnotes.md
# ✅ Сохранено: feedback:createpublictemplate.md
# ✅ Сохранено: Category_aggregation#Simple_weighted_mean.md
# ✅ Сохранено: course:ignorefilesizelimits.md
# ✅ Сохранено: badges:viewbadges.md
# ✅ Сохранено: TinyMCE.md
# ✅ Сохранено: Markdown.md
# ✅ Сохранено: premium:usepermanentpen.md
# ✅ Сохранено: badges:deletebadge.md
# ✅ Сохранено: Grade_points.md
# ✅ Сохранено: How_to_prepare_a_Word_file_for_import_into_a_Book.md
# ✅ Сохранено: Resources_FAQ.md
# ✅ Сохранено: contentbank:manageowncontent.md
# ✅ Сохранено: Mac_Installation.md
# ✅ Сохранено: Select_missing_words_question_type.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/2/2a/Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Сохранено: Code_highlighter_filter.md
# ✅ Сохранено: PoodLL_filter.md
# ✅ Сохранено: Formulas_question_type.md
# ✅ Сохранено: Multimedia_plugins_FAQ.md
# ✅ Сохранено: Git_for_Mac.md
# ✅ Сохранено: Grade_categories.md
# ✅ Сохранено: Grading_forms_publisher.md
# ✅ Сохранено: Roles_FAQ#How_can_I_allow_a_.22test.22_Student_user_to_see_courses_that_are_hidden.3F.md
# ✅ Сохранено: course:managegroups.md
# ❌ Ошибка запроса https://docs.moodle.org/500/en/images_en/archive/2/2a/20250630145556%21Moodle_features_students.pdf: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte
# ✅ Сохранено: user:editprofile.md
# ✅ Сохранено: course:bulkmessaging.md
# ✅ Сохранено: feedback:deletetemplate.md
# ✅ Сохранено: Book_resource.md
# ✅ Сохранено: Antivirus_plugins.md
# ✅ Сохранено: XML.md
# ✅ Сохранено: Wiki_module.md
# ✅ Сохранено: H5P_content_types_format.md
# ✅ Сохранено: Finding_and_Selecting_A_Web_Host.md
# ✅ Сохранено: activities.md
# ✅ Сохранено: report_security_check_embed.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Errors_FAQ
# ✅ Сохранено: premium:usepowerpaste.md
# ✅ Сохранено: course:markcomplete.md
# ✅ Сохранено: report_security_check_configrw.md
# ✅ Сохранено: manual:enrol.md
# ✅ Сохранено: recordrtc:recordvideo.md
# ✅ Сохранено: Grade_aggregation.md
# ✅ Сохранено: Events_list.md
# ✅ Сохранено: contentbank:downloadcontent.md
# ✅ Сохранено: feedback:createprivatetemplate.md
# ✅ Сохранено: VPAT#Moodle_accessibility_conformance_report.md
# ✅ Сохранено: tag:manage.md
# ✅ Сохранено: Using_Assignment#Submission_status.md
# ✅ Сохранено: contentbank:access.md
# ✅ Сохранено: grader:view.md
# ✅ Сохранено: Quiz_grades_report.md
# ✅ Сохранено: completion:view.md
# ✅ Сохранено: badges:viewotherbadges.md
# ✅ Сохранено: Edit_profile.md
# ✅ Сохранено: blog:view.md
# ✅ Сохранено: Google_Docs_repository.md
# ✅ Сохранено: Quiz_submission_notification.md
# ✅ Сохранено: Plagiarism_Prevention_Turnitin.md
# ✅ Сохранено: Nextcloud_repository.md
# ✅ Сохранено: Useful_things_a_teacher_can_do_with_roles.md
# ✅ Сохранено: scales.md
# ✅ Сохранено: OpenAI_API_provider.md
# ✅ Сохранено: Document_converter.md
# ✅ Сохранено: competency:usercompetencyreview.md
# ✅ Сохранено: report_security_check_riskxss.md
# ✅ Сохранено: course_backup.md
# ✅ Сохранено: url:view.md
# ✅ Сохранено: noautolink:use.md
# ✅ Сохранено: Switch_roles.md
# ✅ Сохранено: System_status_report.md
# ✅ Сохранено: course:changeidnumber.md
# ✅ Сохранено: Upload_a_file.md
# ✅ Сохранено: LTI_and_Moodle.md
# ✅ Сохранено: Birthday_block.md
# ✅ Сохранено: tag:edit.md
# ✅ Сохранено: Assignment_settings#Use_marking_allocation.md
# ✅ Сохранено: Forums.md
# ✅ Сохранено: Upgrading#Finishing_the_upgrade.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/MoodleDocs:Style_guide
# ✅ Сохранено: feedback:addinstance.md
# ✅ Сохранено: forum:exportpost.md
# ✅ Сохранено: usertours:managetours.md
# ✅ Сохранено: flickr_public:view.md
# ✅ Сохранено: Accessible_course_design.md
# ✅ Сохранено: Quiz_settings#Question_behaviour.md
# ✅ Сохранено: competency:planviewowndraft.md
# ✅ Сохранено: Secondary_education.md
# ✅ Сохранено: book:edit.md
# ✅ Сохранено: View_profile.md
# ✅ Сохранено: stats:view.md
# ✅ Сохранено: Grade_items#Manual_grade_items.md
# ✅ Сохранено: resource:view.md
# ✅ Сохранено: Plugins_overview.md
# ✅ Сохранено: Grade_item_settings.md
# ...
# ✅ Сохранено: Teams_Technical.md
# ✅ Сохранено: Migrations#Step_1_-_Select_source.md
# ✅ Сохранено: jme.md
# ✅ Сохранено: reportbuilder:viewall.md
# ✅ Сохранено: TestingProcess.md
# ✅ Сохранено: Catalogue_Technical.md
# ✅ Сохранено: Staff#My_courses_page.md
# ✅ Сохранено: user:view.md
# ✅ Сохранено: Turnitin%27s_Moodle_Direct_Integration_-_Frequently_Asked_Questions.md
# ✅ Сохранено: My_programs_and_courses_catalogue_settings.md
# ✅ Сохранено: Organisation_Tenants#Shared_Organisation_Structure.md
# ✅ Сохранено: Migrations#Step_2_-_Options.md
# ✅ Сохранено: Migrations#Step_3_-_Review.md
# ✅ Сохранено: Migrations#Step_3_-_Options.md
# ✅ Сохранено: StudentQuiz_module#Rating_a_question.md
# ✅ Сохранено: Plagiarism_Prevention_Crot_Settings.md
# ✅ Сохранено: Installing_Moodle#Software.md
# ✅ Сохранено: Teams_Tenants.md
# ✅ Сохранено: Installing_Apache,_MySQL_and_PHP.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:AL_Rachels
# ✅ Сохранено: Certificate_templates.md
# ✅ Сохранено: Certificates_Configuration.md
# ✅ Сохранено: Migrations#Migration_Import.md
# ✅ Сохранено: Program_page.md
# ✅ Сохранено: StudentQuiz_module#Reports.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Chris_collman
# ✅ Сохранено: Report_builder_Technical#Custom_report_fields.md
# ✅ Сохранено: Migrations_Tenants.md
# ✅ Сохранено: Staff#Program_page.md
# ✅ Сохранено: Course_certificate_activity.md
# ✅ Сохранено: Upload_users_in_Moodle_Workplace.md
# ✅ Сохранено: Appointments_Configuration.md
# ✅ Сохранено: Signing-up_for_a_Face-to-face_session.md
# ✅ Сохранено: Unicode.md
# ✅ Сохранено: Report_builder_Configuration#Sorting.md
# ✅ Сохранено: Workplace_Programs.md
# ✅ Сохранено: Programs_Technical.md
# ✅ Сохранено: Certifications_Configuration.md
# ✅ Сохранено: User_profiles_in_Moodle_Workplace.md
# ✅ Сохранено: Policy_settings.md
# ✅ Сохранено: Organisation_Configuration#Positions.md
# ✅ Сохранено: openssl.md
# ✅ Сохранено: Translation_priority.md
# ✅ Сохранено: Teams_Configuration.md
# ✅ Сохранено: Staff#Course_cover.md
# ✅ Сохранено: Migrations#Step_5_-_Review.md
# ✅ Сохранено: Report_builder_report_block.md
# ✅ Сохранено: reportbuilder:edit.md
# ✅ Сохранено: Catalogue_Use_cases.md
# ✅ Сохранено: User:P%C3%A1l_Cs%C3%A1nyi.md
# ✅ Сохранено: Regular_Expression_Short-Answer_question_type#Inserting_RegExp_sub-questions_in_Cloze_type_questions.md
# ✅ Сохранено: Catalogue#Fields_to_display_in_the_learning_catalogue_filter.md
# ✅ Сохранено: Portfolio.md
# ✅ Сохранено: Programs_Tenants.md
# ✅ Сохранено: Organisation_Technical.md
# ✅ Сохранено: Multi-tenancy_Technical.md
# ✅ Сохранено: StudentQuiz_module#Contribute.md
# ✅ Сохранено: #Users_report.md
# ✅ Сохранено: reportchart:addinstance.md
# ✅ Сохранено: Organisation_Use_cases.md
# ✅ Сохранено: TexToys.md
# ✅ Сохранено: QuizPort_module.md
# ✅ Сохранено: Installing_PHP_on_Windows.md
# ✅ Сохранено: reportchart:myaddinstance.md
# ✅ Сохранено: User_talk:P%C3%A1l_Cs%C3%A1nyi.md
# ✅ Сохранено: Migrations_Configuration.md
# ✅ Сохранено: Viewing_Questionnaire_responses#Download_in_text_format.md
# ✅ Сохранено: Creating_a_new_Face-to-face_session.md
# ✅ Сохранено: Multi-tenancy_Tenants.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Tim_Hunt/test
# ✅ Сохранено: Adding_a_content_page.md
# ✅ Сохранено: experimental:Finding_and_Selecting_A_Web_Host.md
# ✅ Сохранено: User:Valery_Fremaux.md
# ✅ Сохранено: Report_builder_Configuration#Aggregation_and_Grouping.md
# ✅ Сохранено: Workplace_localisation.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Jeffrey_Silverman
# ✅ Сохранено: OU_multiple_response_question_type_detailed_documentation.md
# ✅ Сохранено: User:Matteo_Scaramuccia.md
# ✅ Сохранено: Turnitin%27s_Moodle_Direct_Integration_(Student_Guide).md
# ✅ Сохранено: LaTeX.md
# ✅ Сохранено: reportbuilder:editall.md
# ✅ Сохранено: Algebra_question_type#Linear_syntax.md
# ✅ Сохранено: Import_questions#Importing_questions_from_an_existing_file.md
# ✅ Сохранено: Integrating_Face-to-face_sessions_on_the_course_page.md
# ✅ Сохранено: Organisation_Configuration#People_&_Jobs.md
# ✅ Сохранено: Organisation_Tenants.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:WIRIS_team_SUPPORT
# ✅ Сохранено: Certifications_Tenants.md
# ✅ Сохранено: Installing_Moodle#Create_the_.28moodledata.29_data_directory.md
# ✅ Сохранено: User:Frank_Ralf.md
# ✅ Сохранено: Staff_Technical.md
# ✅ Сохранено: Obsolete:Step_by_Step_Installation_on_a_Mac_OS_X_Server.md
# ✅ Сохранено: Moodle_Workplace_App_Tenants.md
# ✅ Сохранено: Catalogue_Tenants.md
# ✅ Сохранено: Dynamic_rules_Tenants.md
# ✅ Сохранено: Organisation_Configuration#Departments.md
# ✅ Сохранено: unicode.md
# ✅ Сохранено: Multi-tenancy_Use_cases.md
# ✅ Сохранено: Custom_pages_Technical.md
# ✅ Сохранено: Staff#Program_cover_page.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Marc_Grober
# ✅ Сохранено: Appointments_Technical.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Jean-Michel_V%C3%A9drine
# ✅ Сохранено: Catalogue#Learning_catalogue_settings.md
# ✅ Сохранено: #SQL_report.md
# ✅ Сохранено: Workplace_security.md
# ✅ Сохранено: Migrations#Step_4_-_Conflicts.md
# ✅ Сохранено: Staff_Use_cases.md
# ✅ Сохранено: Workshop_settings#Use_self-assessment.md
# ✅ Сохранено: Teams_Use_cases.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Maths
# ✅ Сохранено: Migrations_Use_cases.md
# ✅ Сохранено: Adminer.md
# ✅ Сохранено: Staff_Configuration.md
# ✅ Сохранено: Organisation_Configuration.md
# ✅ Сохранено: STACK_installation_instructions.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Gordon_Bateson
# ✅ Сохранено: Certificate_issuing.md
# ✅ Сохранено: Custom_pages_Tenants.md
# ✅ Сохранено: editing_a_hotpot.md
# ✅ Сохранено: tags.md
# ✅ Сохранено: Moodle_Workplace_App_Use_cases.md
# ✅ Сохранено: Custom_pages_Use_cases.md
# ✅ Сохранено: Assignment_settings#Submission_settings.md
# ✅ Сохранено: StudentQuiz_module#Ranking_Settings.md
# ✅ Сохранено: Appointments_Tenants.md
# ✅ Сохранено: Workplace_theme.md
# ✅ Сохранено: Translation_langconfig.md
# ✅ Сохранено: Appointment_custom_fields.md
# ✅ Сохранено: Moodle_Workplace_Installation.md
# ✅ Сохранено: Certificate_templates#Image.md
# ✅ Сохранено: Multi-tenancy_Technical#Multi-tenancy_authentication.md
# ✅ Сохранено: JavaScript2.md
# ✅ Сохранено: Programs_Configuration#Completion_criteria.md
# ✅ Сохранено: dynamicrule:manage.md
# ✅ Сохранено: scheduled_tasks.md
# ✅ Сохранено: Dynamic_rules_Configuration#Rule_conditions.md
# ✅ Сохранено: Table_of_locales.md
# ✅ Сохранено: certificate:manageforalltenants.md
# ✅ Сохранено: Multi-tenancy_authentication#Email-based_self-registration.md
# ✅ Сохранено: appointment:signup.md
# ✅ Сохранено: program:manage.md
# ✅ Сохранено: Multi-tenancy_Configuration#Tenant_Branding.md
# ✅ Сохранено: Report_block.md
# ✅ Сохранено: appointment:takeattendance.md
# ✅ Сохранено: Programs_Technical#Program_custom_fields.md
# ✅ Сохранено: Dynamic_rules_Configuration#Rules_header.md
# ✅ Сохранено: catalogue:config.md
# ✅ Сохранено: Workplace_localisation_%26_translation.md
# ✅ Сохранено: Dynamic_rules_Configuration#Rules_enabling_and_processing.md
# ✅ Сохранено: Multi-tenancy#Shared_Space.md
# ✅ Сохранено: program:allocateuser.md
# ✅ Сохранено: program:configurecustomfields.md
# ✅ Сохранено: Appointments#Appointment_Reporting.md
# ✅ Сохранено: organisation:managedepartments.md
# ✅ Сохранено: PHP#Displaying_phpinfo_in_Moodle.md
# ✅ Сохранено: Appointments#Waitlisting.md
# ✅ Сохранено: Groups#Group_modes.md
# ⚠️ HTTP 404 для https://docs.moodle.org/500/en/Development:Firebug
# ✅ Сохранено: Managing_authentication#Profile_fields_data_mapping_and_locking.md
# ✅ Сохранено: Upload_users_in_Moodle_Workplace#Tenant_allocation.md
# ✅ Сохранено: Multi-tenancy_authentication#Login_and_signup_tenant_selector.md
# ✅ Сохранено: Certifications_Configuration#Progress_overview.md
# ✅ Сохранено: Multi-tenancy_Technical#Tenant_administrator_role.md
# ✅ Сохранено: Organisation_Use_cases#Use_Case_1:_Organisation_structure_hierarchy_based_on_departments.md
# ✅ Сохранено: Certificate_element_plugins.md
# ✅ Сохранено: question_bank.md
# ✅ Сохранено: organisation:managepositions.md
# ✅ Сохранено: program:enrol.md
# ✅ Сохранено: tenant:managedashboard.md
# ✅ Сохранено: Hiding_course_upon_end_date.md
# ⛔ Пропущено из-за 'Talk:': https://docs.moodle.org/500/en/User:Frank_Ralf/Subpage_transclusion
# ✅ Сохранено: Windows_installation_using_XAMPP#Moodledata_folder.md
# ✅ Сохранено: Multi-tenancy_Configuration#Managing_tenants.md
# ✅ Сохранено: appointment:configurecancellation.md
# ✅ Сохранено: Programs_Technical#Program_manager_role.md
# ✅ Сохранено: certificate:imageforalltenants.md
# ✅ Сохранено: appointment:viewattendees.md
# ✅ Сохранено: Dynamic_rules#Rules_Enabling_and_Processing.md
# ✅ Сохранено: certification:configurecustomfields.md
# ✅ Сохранено: tenant:manageusers.md
# ✅ Сохранено: Dynamic_rules_Configuration#Courses.md
# ✅ Сохранено: Certifications_Configuration#Recertification.md
# ✅ Сохранено: NanoGong.md
# ✅ Сохранено: Multi-tenancy_Technical#Tenant_user_role.md
# ✅ Сохранено: Migrating_multi-domain_configuration.md
# ✅ Сохранено: Certifications_Configuration#Edit_allocation.md
# ✅ Сохранено: Multi-tenancy_Technical#OAuth_2.md
# ✅ Сохранено: Certificate_templates#Digital_signature.md
# ✅ Сохранено: Certifications_Configuration#Certification_dynamic_rules.md
# ✅ Сохранено: Certifications_Configuration#Certification_users.md
# ✅ Сохранено: XML_FAQ.md
# ✅ Сохранено: Certifications_Tenants#Shared_Certifications.md
# ✅ Сохранено: Certifications#Certifications_Reports.md
# ✅ Сохранено: JavaScript1.md
# ✅ Сохранено: certificate:verify.md
# ✅ Сохранено: tenant:manage.md
# ✅ Сохранено: List_of_locales_supported_on_Moodle_community_servers.md
# ✅ Сохранено: Certificate_issuing#Manually_issuing_of_certificates.md
# ✅ Сохранено: Multi-tenancy_authentication#OAuth_2.md
# ✅ Сохранено: tenant:managethemeadvanced.md
# ✅ Сохранено: overview:view.md
# ✅ Сохранено: Multi-tenancy_authentication#Manual_accounts.md
# ✅ Сохранено: Programs_Configuration#Program_details.md
# ✅ Сохранено: Multi-tenancy_Technical#Tenant_administrator_in_course_category_role.md
# ✅ Сохранено: custompage:editall.md
# ✅ Сохранено: Certificate_issuing#Automatic_issuing_of_certificates_via_dynamic_rules.md
# ✅ Сохранено: appointment:managecustomfields.md
# ✅ Сохранено: Certifications_Configuration#Revoke_certification.md
# ✅ Сохранено: Appointments#Appointment_notifications.md
# ✅ Сохранено: organisation:assigninlocked.md
# ✅ Сохранено: Git.md
# ✅ Сохранено: Moodle_forms1.md
# ✅ Сохранено: appointment:view.md
# ✅ Сохранено: Programs_Configuration#Program_users.md
# ✅ Сохранено: Experience_of_converting_a_module_to_Moodle_2.md
# ✅ Сохранено: Programs#Program_Reports.md
# ✅ Сохранено: Certificate_issuing#Issuing_of_certificates_via_the_Course_certificate_activity.md
# ✅ Сохранено: appointment:viewcancellations.md
# ✅ Сохранено: certification:allocateuser.md
# ✅ Сохранено: Programs_Configuration#Program_reset.md
# ✅ Сохранено: Upload_users_in_Moodle_Workplace#Job_assignments.md
# ✅ Сохранено: certificate:viewallcertificates.md
# ✅ Сохранено: program:unenrol.md
# ✅ Сохранено: Programs_Configuration#Program_Reports.md
# ✅ Сохранено: Dynamic_rules_Configuration#Rule_actions.md
# ✅ Сохранено: certificate:image.md
# ✅ Сохранено: Report_builder#Data_Store.md
# ✅ Сохранено: Git_workflow.md
# ✅ Сохранено: Organisation_Use_cases#Use_Case_2:_Organisation_structure_hierarchy_based_on_positions.md
# ✅ Сохранено: appointment:overbook.md
# ✅ Сохранено: Multi-tenancy#Shared_Content.md
# ✅ Сохранено: program:config.md
# ✅ Сохранено: Certificate_verification.md
# ✅ Сохранено: dynamicrule:enrol.md
# ✅ Сохранено: program:edit.md
# ✅ Сохранено: Certificate_images.md
# ✅ Сохранено: Multi-tenancy_Configuration#Tenant_Authentication.md
# ✅ Сохранено: Moodle_HTML.md
# ✅ Сохранено: certificate:issueforalltenants.md
# ✅ Сохранено: appointment:addinstance.md
# ✅ Сохранено: coursecertificate:addinstance.md
# ✅ Сохранено: appointment:removeattendees.md
# ✅ Сохранено: Certifications_Configuration#Delete_allocation.md
# ✅ Сохранено: organisation:assignjobs.md
# ✅ Сохранено: My_courses_page.md
# ✅ Сохранено: question_types.md
# ✅ Сохранено: dynamicrule:unenrol.md
# ✅ Сохранено: tenant:allocate.md
# ✅ Сохранено: Multi-tenancy_Tenants#Shared_Content.md
# ✅ Сохранено: appointment:addattendees.md
# ✅ Сохранено: Migrations#Step_3b_-_Options_(Importing_a_file_in_CSV_format).md
# ✅ Сохранено: coursecertificate:receive.md
# ✅ Сохранено: custompage:viewall.md
# ✅ Сохранено: tenant:browseusers.md
# ✅ Сохранено: coursecertificate:viewreport.md
# ✅ Сохранено: certificate:verifyforalltenants.md
# ✅ Сохранено: Catalogue#Making_the_Learning_Catalogue_Public.md
# ✅ Сохранено: Moodle_2.1_sections_proposal.md
# ✅ Сохранено: Programs_Configuration#Program_schedule.md
# ✅ Сохранено: program:coursereset.md
# ✅ Сохранено: certificate:manage.md
# ✅ Сохранено: Programs_Configuration#Program_completion_re-calculation.md
# ✅ Сохранено: dynamicrule:config.md
# ✅ Сохранено: Catalogue#Fields_to_search_for_keywords.md
# ✅ Сохранено: Organisation_Technical#Organisation_structure_manager_role.md
# ✅ Сохранено: Upload_users_in_Moodle_Workplace#Programs_and_certifications_allocations.md
# ✅ Сохранено: certificate:issue.md
# ✅ Сохранено: appointment:editsessions.md
# ✅ Сохранено: custompage:skipblockvalidation.md
# ✅ Сохранено: Programs_Tenants#Sharing_content_across_tenants.md
# ✅ Сохранено: custompage:edit.md
# ✅ Сохранено: certification:edit.md
# ✅ Сохранено: Dynamic_rules_Configuration#Notification_placeholders.md
# ✅ Сохранено: Glossary_list.md
# ✅ Сохранено: tenant:authconfig.md
# ✅ Сохранено: Appointments#Signing_up.md
# ✅ Сохранено: tenant:mobileconfig.md
# ✅ Сохранено: Certifications_Configuration#Certification_activity_log.md
# ✅ Сохранено: QuizPort.md
# ✅ Сохранено: Multi-tenancy_authentication#SAML.md
# ✅ Сохранено: Certifications_Configuration#Certify_users.md
# ✅ Сохранено: Certifications_Configuration#Initial_certification.md
# ✅ Сохранено: Certifications#Certification_users.md
# ✅ Сохранено: site:config.md
# ✅ Сохранено: Multi-tenancy_Technical#Login_and_signup_tenant_selector.md
# ✅ Сохранено: Certificate_templates#Code.md
# ✅ Сохранено: coursecertificate:view.md
# ✅ Сохранено: Programs_Configuration#Program_Archive.md
# ✅ Сохранено: tenant:managetheme.md
# ✅ Сохранено: Dynamic_rules_Configuration#Multi-language_support_in_notifications.md
# ✅ Сохранено: organisation:assignmanuallymgr.md
# ✅ Сохранено: Tenant_administrator_role.md
# ✅ Сохранено: Glossary_list2.md
# ✅ Сохранено: Semantic_HTML3.md
# ✅ Сохранено: AJAX.md
# ✅ Сохранено: Appointments#Booking_a_place_for_another_user.md
# ✅ Сохранено: Development:YUI.md
# ✅ Сохранено: My_Moodle_Git_workflow.md
# ✅ Сохранено: Semantic_HTML2.md
# ✅ Сохранено: Upgrading#Install_the_new_Moodle_software.md
# ✅ Сохранено: Appointments#Attendance.md
# ✅ Сохранено: Appointments#Cancellation.md
# ✅ Сохранено: Appointments#Appointments_and_sessions.md
# ✅ Сохранено: 1.9.md
# ✅ Сохранено: Semantic_HTML4.md
# ✅ Сохранено: Moodle_forms2.md
# ✅ Сохранено: Moodle_forms3.md
# ✅ Сохранено: Organisation_manager_role.md
# ✅ Сохранено: Dynamic_rules#Courses.md
# ✅ Сохранено: Multi-tenancy#Multi-tenancy_domain_configuration.md
# ✅ Сохранено: Semantic_HTML5.md
# ✅ Сохранено: Development:Progressive_enhancement.md
# ⚠️ HTTP 404 для https://docs.moodle.org/500/en/Development:Unobtrusive_Javascript
# ✅ Сохранено: Program_manager_role.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/Obsolete:Moodle_forms_library
# ✅ Сохранено: Custom_Context_Levels.md
# ✅ Сохранено: Development:Roles_administration_improvements_for_Moodle_2.0.md
# ✅ Сохранено: Development:Roles#Programming_Interface.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Sam_Hemelryk
# ✅ Сохранено: AJAX_and_Javascript_settings.md
# ✅ Сохранено: Development:Roles_and_modules#Context.md
# ⛔ Пропущено из-за 'Category:': https://docs.moodle.org/500/en/Development:lib/formslib.php_Form_Definition
# ✅ Сохранено: Development:Competencies.md
# ⛔ Пропущено из-за короткого текста (<300 символов): https://docs.moodle.org/500/en/User:Hubert_Chathi

# %%
import os

folder_path = '/content/drive/MyDrive/moodle_docs9'  # укажи свой путь

file_count = sum(len(files) for _, _, files in os.walk(folder_path))
print(f"Всего файлов: {file_count}")
# Out:
# Всего файлов: 2312
